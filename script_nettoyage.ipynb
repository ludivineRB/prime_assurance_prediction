# %% [markdown]
# ## Script de nettoyage du fichier csv

# %%
# Import des librairies
import numpy as np
import pandas as pd

# %%
# Création du dataframe
data = pd.read_csv("assurance_data.csv")
data.head(10)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# 5   31  female  25.740         0     no  southeast   3756.62160
# 6   46  female  33.440         1     no  southeast   8240.58960
# 7   37  female  27.740         3     no  northwest   7281.50560
# 8   37    male  29.830         2     no  northeast   6406.41070
# 9   60  female  25.840         0     no  northwest  28923.13692

# %%
sample = data.head(20)
sample
# Out:
#     age     sex     bmi  children smoker     region      charges
# 0    19  female  27.900         0    yes  southwest  16884.92400
# 1    18    male  33.770         1     no  southeast   1725.55230
# 2    28    male  33.000         3     no  southeast   4449.46200
# 3    33    male  22.705         0     no  northwest  21984.47061
# 4    32    male  28.880         0     no  northwest   3866.85520
# 5    31  female  25.740         0     no  southeast   3756.62160
# 6    46  female  33.440         1     no  southeast   8240.58960
# 7    37  female  27.740         3     no  northwest   7281.50560
# 8    37    male  29.830         2     no  northeast   6406.41070
# 9    60  female  25.840         0     no  northwest  28923.13692
# 10   25    male  26.220         0     no  northeast   2721.32080
# 11   62  female  26.290         0    yes  southeast  27808.72510
# 12   23    male  34.400         0     no  southwest   1826.84300
# ...

# %%
sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       20 non-null     int64
#  1   sex       20 non-null     object
#  2   bmi       20 non-null     float64
#  3   children  20 non-null     int64
#  4   smoker    20 non-null     object
#  5   region    20 non-null     object
#  6   charges   20 non-null     float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 1.2+ KB

# %%
# transformer le boolean yes/no vers 1/0 et convertir les valeur en int
# sample['smoker'] = sample['smoker'].map({"yes":"1","no":"0"})
sample.loc[0,'smoker'] = "1"
sample
# Out:
#     age     sex     bmi  children smoker     region      charges
# 0    19  female  27.900         0      1  southwest  16884.92400
# 1    18    male  33.770         1      0  southeast   1725.55230
# 2    28    male  33.000         3      0  southeast   4449.46200
# 3    33    male  22.705         0      0  northwest  21984.47061
# 4    32    male  28.880         0      0  northwest   3866.85520
# 5    31  female  25.740         0      0  southeast   3756.62160
# 6    46  female  33.440         1      0  southeast   8240.58960
# 7    37  female  27.740         3      0  northwest   7281.50560
# 8    37    male  29.830         2      0  northeast   6406.41070
# 9    60  female  25.840         0      0  northwest  28923.13692
# 10   25    male  26.220         0      0  northeast   2721.32080
# 11   62  female  26.290         0      1  southeast  27808.72510
# 12   23    male  34.400         0      0  southwest   1826.84300
# ...

# %%
sample['smoker'] = sample['smoker'].astype(int)
sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       20 non-null     int64
#  1   sex       20 non-null     object
#  2   bmi       20 non-null     float64
#  3   children  20 non-null     int64
#  4   smoker    20 non-null     int64
#  5   region    20 non-null     object
#  6   charges   20 non-null     float64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 1.2+ KB
# C:\Users\nicol\AppData\Local\Temp\ipykernel_11748\602737774.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample['smoker'] = sample['smoker'].astype(int)
