# %% [markdown]
# ## Visualisation du dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Création du dataframe
df = pd.read_csv("assurance_dataset_clean.csv")
df.head(5)
# Out:
#    age     sex     bmi  children  smoker     region      charges
# 0   19  female  27.900         0    True  southwest  16884.92400
# 1   18    male  33.770         1   False  southeast   1725.55230
# 2   28    male  33.000         3   False  southeast   4449.46200
# 3   33    male  22.705         0   False  northwest  21984.47061
# 4   32    male  28.880         0   False  northwest   3866.85520

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1337 entries, 0 to 1336
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1337 non-null   int64
#  1   sex       1337 non-null   object
#  2   bmi       1337 non-null   float64
#  3   children  1337 non-null   int64
#  4   smoker    1337 non-null   bool
#  5   region    1337 non-null   object
#  6   charges   1337 non-null   float64
# dtypes: bool(1), float64(2), int64(2), object(2)
# memory usage: 64.1+ KB

# %%
# Visualisation globale des données
sns.pairplot(data=df)
plt.show()

# %%
# Visualisation des données en fonction du sexe
sns.pairplot(data=df, hue='sex')
plt.show()

# %%
# Visualisation des données en fonction da qualité de fumeur
sns.pairplot(data=df, hue='smoker')
plt.show()

# %%
# Visualisation des données en fonction des régions
sns.pairplot(data=df, hue='region')
plt.show()
